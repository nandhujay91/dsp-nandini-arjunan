# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\navee\miniconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\navee\miniconda3\lib\site-packages (from pandas) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\navee\miniconda3\lib\site-packages (from pandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\navee\miniconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\navee\miniconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\navee\miniconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\navee\miniconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\navee\miniconda3\lib\site-packages (from scikit-learn) (2.0.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\navee\miniconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\navee\miniconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\navee\miniconda3\lib\site-packages (from scikit-learn) (3.5.0)

# %%
pip show scikit-learn
# Out:
# Name: scikit-learn
# Version: 1.5.1
# Summary: A set of python modules for machine learning and data mining
# Home-page: https://scikit-learn.org
# Author:
# Author-email:
# License: new BSD
# Location: c:\users\navee\miniconda3\lib\site-packages
# Requires: joblib, numpy, scipy, threadpoolctl
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
# !ls ../data
# Out:
# data_description.txt
# sample_submission.csv
# test.csv
# train.csv

# %%
import pandas as pd

DATA_FILENAME = '../data/train.csv'

# %% [markdown]
# # Read data

# %% [markdown]
# - Read data

# %%
df_raw = pd.read_csv(DATA_FILENAME)

# %% [markdown]
# - Show head of data (first 5 rows)

# %%
df_raw.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
df_raw.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [5 rows x 81 columns]

# %%
df_raw.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 5         Lvl    AllPub  ...        0    NaN  MnPrv        Shed     700
# 6         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 7         Lvl    AllPub  ...        0    NaN    NaN        Shed     350
# 8         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 9         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
# 5     10   2009        WD         Normal     143000
# 6      8   2007        WD         Normal     307000
# 7     11   2009        WD         Normal     200000
# 8      4   2008        WD        Abnorml     129900
# 9      1   2008        WD         Normal     118000
#
# [10 rows x 81 columns]

# %% [markdown]
# - check how many rows you have in the data

# %%
df_raw.shape
# Out:
# (1460, 81)

# %% [markdown]
# - Filter data

# %%
label_col = 'SalePrice'
useful_features = ['Foundation', 'KitchenQual', 'ExterQual','TotRmsAbvGrd', 'WoodDeckSF', 'YrSold', '1stFlrSF']

# %%
df = df_raw[useful_features + [label_col]]
df.head()
# Out:
#   Foundation KitchenQual ExterQual  TotRmsAbvGrd  WoodDeckSF  YrSold  \
# 0      PConc          Gd        Gd             8           0    2008
# 1     CBlock          TA        TA             6         298    2007
# 2      PConc          Gd        Gd             6           0    2008
# 3     BrkTil          Gd        TA             7           0    2006
# 4      PConc          Gd        Gd             9         192    2008
#
#    1stFlrSF  SalePrice
# 0       856     208500
# 1      1262     181500
# 2       920     223500
# 3       961     140000
# 4      1145     250000

# %%
df.shape
# Out:
# (1460, 8)

# %% [markdown]
# # Preprocess data

# %%
continuous_features = ['TotRmsAbvGrd', 'YrSold']
discrete_features = ['Foundation', 'KitchenQual']
features_to_one_hot_encode = ['Foundation']
features_to_oridinal_encode = ['KitchenQual','ExterQual']

# %% [markdown]
# - check the values and the count of a given feature

# %%
df['Foundation'].value_counts()
# Out:
# Foundation
# PConc     647
# CBlock    634
# BrkTil    146
# Slab       24
# Stone       6
# Wood        3
# Name: count, dtype: int64

# %%
df['TotRmsAbvGrd'].value_counts()
# Out:
# TotRmsAbvGrd
# 6     402
# 7     329
# 5     275
# 8     187
# 4      97
# 9      75
# 10     47
# 11     18
# 3      17
# 12     11
# 2       1
# 14      1
# Name: count, dtype: int64

# %%
df['KitchenQual'].value_counts()
# Out:
# KitchenQual
# TA    735
# Gd    586
# Ex    100
# Fa     39
# Name: count, dtype: int64

# %%
df['ExterQual'].value_counts()
# Out:
# ExterQual
# TA    906
# Gd    488
# Ex     52
# Fa     14
# Name: count, dtype: int64

# %% [markdown]
# ## encoding

# %%
df_one_hot_code = pd.get_dummies(df[features_to_one_hot_encode])
df_one_hot_code.head()
# Out:
#    Foundation_BrkTil  Foundation_CBlock  Foundation_PConc  Foundation_Slab  \
# 0              False              False              True            False
# 1              False               True             False            False
# 2              False              False              True            False
# 3               True              False             False            False
# 4              False              False              True            False
#
#    Foundation_Stone  Foundation_Wood
# 0             False            False
# 1             False            False
# 2             False            False
# 3             False            False
# 4             False            False

# %% [markdown]
# ## TODO
# - categorize the rest of features
# - scale continuous features (df_scaled)
# - ordinal encode categorical features (quality, etc) (df_ordinal_encoded)
# - Concat the 3 dataframes in a single one (df_one_hot_code, df_ordinal_encoded, df_scaled)

# %%
from sklearn.preprocessing import StandardScaler, OrdinalEncoder, OneHotEncoder

# %%
ordinal_features = ['KitchenQual','ExterQual']
ordinal_categories = [
    ['Fa', 'TA', 'Gd', 'Ex'], 
    ['Fa', 'TA', 'Gd', 'Ex']   
]
ordinal_encoder = OrdinalEncoder(categories=ordinal_categories)
df_ordinal_encoded = pd.DataFrame(ordinal_encoder.fit_transform(df[ordinal_features]), columns=ordinal_features)

# %%
scaler = StandardScaler()
df_scaled = pd.DataFrame(scaler.fit_transform(df[continuous_features]), columns=continuous_features)

# %%
df_final = pd.concat([df_one_hot_code, df_ordinal_encoded, df_scaled, df['SalePrice']], axis=1)

# %%
df_final.head(20)
# Out:
#     Foundation_BrkTil  Foundation_CBlock  Foundation_PConc  Foundation_Slab  \
# 0               False              False              True            False
# 1               False               True             False            False
# 2               False              False              True            False
# 3                True              False             False            False
# 4               False              False              True            False
# 5               False              False             False            False
# 6               False              False              True            False
# 7               False               True             False            False
# 8                True              False             False            False
# 9                True              False             False            False
# 10              False               True             False            False
# 11              False              False              True            False
# 12              False               True             False            False
# 13              False              False              True            False
# 14              False               True             False            False
# 15               True              False             False            False
# 16              False               True             False            False
# 17              False              False             False             True
# 18              False              False              True            False
# 19              False               True             False            False
#
#     Foundation_Stone  Foundation_Wood  KitchenQual  ExterQual  TotRmsAbvGrd  \
# 0              False            False          2.0        2.0      0.912210
# 1              False            False          1.0        1.0     -0.318683
# 2              False            False          2.0        2.0     -0.318683
# 3              False            False          2.0        1.0      0.296763
# 4              False            False          2.0        2.0      1.527656
# 5              False             True          1.0        1.0     -0.934130
# 6              False            False          2.0        2.0      0.296763
# 7              False            False          1.0        1.0      0.296763
# 8              False            False          1.0        1.0      0.912210
# 9              False            False          1.0        1.0     -0.934130
# 10             False            False          1.0        1.0     -0.934130
# 11             False            False          3.0        3.0      2.758549
# 12             False            False          1.0        1.0     -1.549576
# 13             False            False          2.0        2.0      0.296763
# 14             False            False          1.0        1.0     -0.934130
# 15             False            False          1.0        1.0     -0.934130
# 16             False            False          1.0        1.0     -0.934130
# 17             False            False          1.0        1.0     -0.318683
# 18             False            False          2.0        1.0     -0.318683
# 19             False            False          1.0        1.0     -0.318683
#
#       YrSold  SalePrice
# 0   0.138777     208500
# 1  -0.614439     181500
# 2   0.138777     223500
# 3  -1.367655     140000
# 4   0.138777     250000
# 5   0.891994     143000
# 6  -0.614439     307000
# 7   0.891994     200000
# 8   0.138777     129900
# 9   0.138777     118000
# 10  0.138777     129500
# 11 -1.367655     345000
# 12  0.138777     144000
# 13 -0.614439     279500
# 14  0.138777     157000
# 15 -0.614439     132000
# 16  1.645210     149000
# 17 -1.367655      90000
# 18  0.138777     159000
# 19  0.891994     139000

# %% [markdown]
# # Training

# %% [markdown]
# - Create X and y

# %%
X, y = df_final.drop(columns=[label_col]), df_final[label_col]

# %% [markdown]
# - Split data in X_train, y_train, X_test, y_test https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html

# %%
# TODO
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=30)

# %% [markdown]
# - Instantiate a LinearRegressor https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html

# %%
# TODO
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %% [markdown]
# - Train the model (model.fit ...)

# %%
# TODO
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Evaluation

# %% [markdown]
# - make predictions (`y_pred = model.predict(X_test)`)

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# - compute performance using https://scikit-learn.org/stable/modules/generated/sklearn.metrics.root_mean_squared_error.html#sklearn.metrics.root_mean_squared_error

# %%
import numpy as np
from sklearn.metrics import mean_squared_log_error

def compute_rmsle(y_test: np.ndarray, y_pred: np.ndarray, precision: int = 2) -> float:
    rmsle = np.sqrt(mean_squared_log_error(y_test, y_pred))
    return round(rmsle, precision)

# %%
rmsle = compute_rmsle(y_test,y_pred)
print(f'Root Mean Squared Logarithmic Error (RMSLE): {rmsle}')
# Out:
# Root Mean Squared Logarithmic Error (RMSLE): 0.26
