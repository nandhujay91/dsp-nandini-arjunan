# %%
import numpy as np
from IPython.display import display

my_array = np.random.randint(10, size=(10, 3))
display(my_array)
# Out:
# array([[5, 7, 0],
#        [1, 5, 7],
#        [6, 4, 3],
#        [5, 8, 2],
#        [8, 7, 0],
#        [0, 8, 3],
#        [9, 8, 8],
#        [9, 1, 9],
#        [0, 7, 8],
#        [4, 9, 2]])
