# %%
import numpy as np
my_array = np.random.randint(0, 100, size=(10, 3))
display(my_array)
# Out:
# array([[61, 31,  7],
#        [48, 84, 77],
#        [24, 58, 73],
#        [41, 70, 96],
#        [12, 84, 40],
#        [90, 42, 52],
#        [94, 32, 89],
#        [62, 96, 70],
#        [40, 88, 24],
#        [59, 86, 78]])
